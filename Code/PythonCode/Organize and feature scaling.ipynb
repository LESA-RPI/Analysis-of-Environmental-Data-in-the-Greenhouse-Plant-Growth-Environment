# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data1 = pd.read_excel('StrawberryOrganizedScaled.xlsx')

# %%
data1 = pd.read_excel('TomatoesTarget_CO2.xlsx')
data1
# Out:
#    Total Weight  Fruit Number  Fruit Fresh Weight (3)    Brix  Truss Weight  \
# 0       1524.32           181                 527.330  209.30        175.39
# 1       1519.75           155                 569.710  205.30        233.72
# 2       1919.16           193                 644.538  240.10        265.00
# 3       1955.29           204                 611.110  254.90        325.46
# 4       2686.77           294                 832.540  239.85        455.50
# 5       1532.85           188                 496.450  235.80        316.83
# 6       1116.37           180                 425.650  230.35        294.18
# 7       1037.11           172                 356.040  227.75        214.77
# 8       1004.59           196                 311.460  238.55        154.49
# 9        868.63           162                 279.530  161.30        119.28
#
#    Total Fruit Weight  Fruit Dry Weight (3)       D/F    Total DW  \
# ...

# %%
data1 = data1.cumsum()
data1
# Out:
#    Total Weight  Fruit Number  Fruit Fresh Weight (3)     Brix  Truss Weight  \
# 0       1524.32           181                 527.330   209.30        175.39
# 1       3044.07           336                1097.040   414.60        409.11
# 2       4963.23           529                1741.578   654.70        674.11
# 3       6918.52           733                2352.688   909.60        999.57
# 4       9605.29          1027                3185.228  1149.45       1455.07
# 5      11138.14          1215                3681.678  1385.25       1771.90
# 6      12254.51          1395                4107.328  1615.60       2066.08
# 7      13291.62          1567                4463.368  1843.35       2280.85
# 8      14296.21          1763                4774.828  2081.90       2435.34
# 9      15164.84          1925                5054.358  2243.20       2554.62
#
#    Total Fruit Weight  Fruit Dry Weight (3)        D/F     Total DW  \
# ...

# %%
df_norm = (data1-data1.min())/(data1.max()-data1.min())
df_norm
# Out:
#    Total Weight  Fruit Number  Fruit Fresh Weight (3)      Brix  Truss Weight  \
# 0      0.000000      0.000000                0.000000  0.000000      0.000000
# 1      0.111414      0.088876                0.125846  0.100939      0.098233
# 2      0.252110      0.199541                0.268222  0.218988      0.209614
# 3      0.395454      0.316514                0.403213  0.344314      0.346406
# 4      0.592424      0.485092                0.587118  0.462240      0.537855
# 5      0.704799      0.592890                0.696781  0.578175      0.671020
# 6      0.786641      0.696101                0.790805  0.691430      0.794665
# 7      0.862672      0.794725                0.869453  0.803407      0.884933
# 8      0.936320      0.907110                0.938253  0.920694      0.949866
# 9      1.000000      1.000000                1.000000  1.000000      1.000000
#
#    Total Fruit Weight  Fruit Dry Weight (3)       D/F  Total DW  \
# ...

# %%
target = pd.read_csv('CornellStrawberryHarvestSumData.csv').drop('Harvest #', axis=1)
target = target.loc[target.index % 2 == 1] #0 is CO2 and 1 is Control
target = target.loc[target['Cultivar'] == 'CA']
target = target.drop('Treatment', axis=1).drop('Cultivar', axis=1)
target = target.cumsum()
target
# Out:
#       TB#     TBFW  Mean TBFW/Berry  MB#    MBFW  Mean MBFW/Berry
# 55     26    534.1        22.330476    7   162.3        24.330000
# 57     37    838.1        55.663810   12   364.3        64.380000
# 59     58   1077.6        66.098333   20   491.4        81.442500
# 61    111   1663.2        75.951515   41   872.9        98.580714
# 63    129   1771.1        82.849134   46   938.5       111.055714
# 65    184   2218.2        92.069829   64  1198.5       128.171905
# 67    241   2908.5       104.101440   84  1596.9       145.069312
# 69    293   3305.5       112.020606   90  1695.3       164.389312
# 71    333   3549.2       117.897360   98  1754.4       175.182646
# 73    381   4021.6       127.704438  109  1924.8       191.409729
# 75    457   4599.6       135.781250  125  2220.8       210.491210
# 77    540   5504.0       146.544296  152  2514.2       220.761766
# 79    623   6293.0       156.571624  182  2923.9       234.620251
# ...

# %%
target_norm = (target-target.min())/(target.max()-target.min())
target_norm
# Out:
#           TB#      TBFW  Mean TBFW/Berry       MB#      MBFW  Mean MBFW/Berry
# 55   0.000000  0.000000         0.000000  0.000000  0.000000         0.000000
# 57   0.006115  0.018753         0.127262  0.007508  0.022219         0.101858
# 59   0.017788  0.033526         0.167100  0.019520  0.036199         0.145252
# 61   0.047248  0.069650         0.204718  0.051051  0.078161         0.188839
# 63   0.057254  0.076306         0.231052  0.058559  0.085376         0.220566
# 65   0.087827  0.103886         0.266256  0.085586  0.113975         0.264097
# 67   0.119511  0.146468         0.312191  0.115616  0.157796         0.307072
# 69   0.148416  0.170957         0.342425  0.124625  0.168619         0.356208
# 71   0.170650  0.185990         0.364862  0.136637  0.175120         0.383658
# 73   0.197332  0.215130         0.402304  0.153153  0.193862         0.424928
# 75   0.239578  0.250785         0.433140  0.177177  0.226420         0.473457
# ...

# %%
target_norm.to_excel(r'C:\Users\shenyutao\Desktop\Summer2022\LESA\data\GH_Tomato\organized data\Strawberry_Target_CA.xlsx')
